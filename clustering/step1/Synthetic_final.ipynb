# %%
import re as splitter
import pandas as pd

# %%
ds=pd.read_csv('s3://vivek2511/sample_geo.txt',delimiter='\t',engine='python')

# %%
ds.head()
# Out:
#     Latitude  Longitude  LocationID
# 0  37.772539 -77.499550           1
# 1  42.090133 -87.689156           2
# 2  39.563418 -75.587532           3
# 3  39.453023 -87.693741           4
# 4  38.953799 -77.016563           5

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

fig=plt.figure(figsize=(12,9))

m=Basemap(projection='mill',llcrnrlat=-90,urcrnrlat=90,llcrnrlon=-180,urcrnrlon=180,resolution='c')
m.drawcoastlines()
m.drawparallels(np.arange(-90,90,10),labels=[True,False,False,False])
m.drawmeridians(np.arange(-180,180,30),labels=[0,0,0,1])
m.scatter(ds['Longitude'].tolist(),ds['Latitude'].tolist(),latlon=True)
plt.title('Basemap tutorial',fontsize=20)
plt.show()

# %% [markdown]
# ![2.PNG](attachment:2.PNG)
